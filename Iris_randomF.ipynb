# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import datasets
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
from sklearn.metrics import classification_report, accuracy_score
from sklearn.feature_selection import SelectKBest, chi2, RFE

# %matplotlib inline

# %%
iris = sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
X = iris.drop('species', axis=1)
y = iris['species']

# %% [markdown]
# #### USING K_BEST

# %%
k_selector = SelectKBest(chi2, k=4)
k_selector.fit(X, y)
# Out:
# SelectKBest(k=4, score_func=<function chi2 at 0x000001B5A1D8C790>)

# %%
k_selector.get_support(indices=True)
# Out:
# array([0, 1, 2, 3], dtype=int64)

# %%
X1 = iris[X.columns[k_selector.get_support()]]
X1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# #### Using RFE

# %%
r_selector = RFE(RandomForestClassifier())
r_selector.fit(X, y)
# Out:
# RFE(estimator=RandomForestClassifier())

# %%
r_selector.support_
# Out:
# array([False, False,  True,  True])

# %%
r_selector.ranking_
# Out:
# array([2, 3, 1, 1])

# %%
# X.columns[r_selector.support_]

# %%
X2 = iris[X.columns[r_selector.support_]]

# %% [markdown]
# #### Using train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=3)
X1_train, X1_test, y_train, y_test = train_test_split(X1, y, test_size=0.3, random_state=3)
X2_train, X2_test, y_train, y_test = train_test_split(X2, y, test_size=0.3, random_state=3)

# %%
def Model(X_train, y_train, X_test):
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    return y_pred

# %%
a_predictions = Model(X_train, y_train, X_test)
print(classification_report(a_predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.86      1.00      0.92        12
#    virginica       1.00      0.88      0.93        16
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.96      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
b_predictions = Model(X1_train, y_train, X1_test)
print(classification_report(b_predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.93      0.93      0.93        14
#    virginica       0.93      0.93      0.93        14
#
#     accuracy                           0.96        45
#    macro avg       0.95      0.95      0.95        45
# weighted avg       0.96      0.96      0.96        45

# %%
c_predictions = Model(X2_train, y_train, X2_test)
print(classification_report(c_predictions, y_test))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.93      1.00      0.96        13
#    virginica       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45

# %% [markdown]
# ### USING GRIDSEARCHCV

# %%
np.random.randint(2, 10, 5)
# Out:
# array([4, 4, 5, 2, 6])

# %%
param_grid = {'n_estimators':np.random.randint(10, 100, 5),
    'criterion':['gini', 'entropy'],
    'min_samples_split':[2, 3, 4],
    'min_samples_leaf':[1, 2, 3, 4],
    'max_features':[2, 3] }

# %%
grid = GridSearchCV(RandomForestClassifier(), param_grid, verbose=3)
grid.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 240 candidates, totalling 1200 fits
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.1s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=1.000 total time=   0.1s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=1.000 total time=   0.2s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=1.000 total time=   0.2s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=14;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=1, min_samples_split=4, n_estimators=65;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=14;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=2, n_estimators=65;, score=0.857 total time=   0.1s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=36;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=60;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.2s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=60;, score=1.000 total time=   0.2s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=3, n_estimators=65;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=60;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=60;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=65;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=65;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=2, min_samples_split=4, n_estimators=65;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=40;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=65;, score=0.905 total time=   0.2s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=2, n_estimators=65;, score=0.857 total time=   0.1s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.1s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=60;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.1s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=1.000 total time=   0.2s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.2s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=2, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=60;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=14;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=2, n_estimators=65;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=36;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=1.000 total time=   0.1s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=40;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.1s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=1.000 total time=   0.1s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=14;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.2s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=1.000 total time=   0.1s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=3, n_estimators=65;, score=0.810 total time=   0.0s
# [CV 1/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=gini, max_features=3, min_samples_leaf=1, min_samples_split=4, n_estimators=36;, score=0.810 total time=   0.0s
# ...
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=14;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=0.952 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=1.000 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=3, min_samples_split=4, n_estimators=65;, score=0.857 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=0.905 total time=   0.1s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=0.952 total time=   0.1s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=1.000 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=60;, score=0.905 total time=   0.1s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.1s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.2s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=0.952 total time=   0.1s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=2, n_estimators=65;, score=0.857 total time=   0.2s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=40;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=3, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=36;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=40;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=60;, score=0.857 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=14;, score=0.905 total time=   0.0s
# [CV 1/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=0.905 total time=   0.0s
# [CV 2/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 3/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=0.952 total time=   0.0s
# [CV 4/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=1.000 total time=   0.0s
# [CV 5/5] END criterion=entropy, max_features=3, min_samples_leaf=4, min_samples_split=4, n_estimators=65;, score=0.905 total time=   0.0s
# GridSearchCV(estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_features': [2, 3],
#                          'min_samples_leaf': [1, 2, 3, 4],
#                          'min_samples_split': [2, 3, 4],
#                          'n_estimators': array([36, 40, 60, 14, 65])},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'criterion': 'gini',
#  'max_features': 2,
#  'min_samples_leaf': 2,
#  'min_samples_split': 2,
#  'n_estimators': 40}

# %%
grid.best_estimator_
# Out:
# RandomForestClassifier(max_features=2, min_samples_leaf=2, n_estimators=40)

# %%
newpred = grid.predict(X_test)

# %%
print(classification_report(newpred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        17
#   versicolor       0.93      1.00      0.96        13
#    virginica       1.00      0.93      0.97        15
#
#     accuracy                           0.98        45
#    macro avg       0.98      0.98      0.98        45
# weighted avg       0.98      0.98      0.98        45
